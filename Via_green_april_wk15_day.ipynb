# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np
import os
os.chdir("D:\Dropbox\Data-Analysis\Via\project\data")

# %%
df = pd.read_csv('green%2Fwk15_sun.csv')
df.head()
# Out:
#            pickup_datetime  trip_time  trip_distance  pickup_long  pickup_lat  \
# 0  2015-04-12 00:40:18 UTC        160           0.29     -73.9749     40.6808
# 1  2015-04-12 00:10:47 UTC        210           0.58     -73.9505     40.6716
# 2  2015-04-12 00:49:50 UTC        249           0.90     -73.8299     40.7137
# 3  2015-04-12 00:24:02 UTC         68           0.01     -73.8811     40.7562
# 4  2015-04-12 00:30:10 UTC        248           0.57     -73.9673     40.6836
#
#    dropoff_long  dropoff_lat  passenger_count  hour  dayofweek
# 0      -73.9777      40.6846                1     0          1
# 1      -73.9397      40.6710                1     0          1
# 2      -73.8333      40.7066                1     0          1
# 3      -73.8830      40.7559                4     0          1
# 4      -73.9607      40.6859                1     0          1

# %% [markdown]
# # Geocoder add zipcode and neighborhood

# %%
df['pickup_long'] = df['pickup_long'].astype(str)
df['pickup_lat'] = df['pickup_lat'].astype(str)
df['dropoff_long'] = df['dropoff_long'].astype(str)
df['dropoff_lat'] = df['dropoff_lat'].astype(str)
df['pickup_coord']=df[['pickup_lat', 'pickup_long']].apply(lambda x: ",".join(x), axis=1)
df['dropoff_coord']=df[['dropoff_lat', 'dropoff_long']].apply(lambda x: ",".join(x), axis=1)
df.drop(['pickup_long','pickup_lat','dropoff_long','dropoff_lat'],axis=1,inplace=True)
df.head()
# Out:
#            pickup_datetime  trip_time  trip_distance  passenger_count  hour  \
# 0  2015-04-12 00:40:18 UTC        160           0.29                1     0
# 1  2015-04-12 00:10:47 UTC        210           0.58                1     0
# 2  2015-04-12 00:49:50 UTC        249           0.90                1     0
# 3  2015-04-12 00:24:02 UTC         68           0.01                4     0
# 4  2015-04-12 00:30:10 UTC        248           0.57                1     0
#
#    dayofweek      pickup_coord     dropoff_coord
# 0          1  40.6808,-73.9749  40.6846,-73.9777
# 1          1  40.6716,-73.9505   40.671,-73.9397
# 2          1  40.7137,-73.8299  40.7066,-73.8333
# 3          1  40.7562,-73.8811   40.7559,-73.883
# 4          1  40.6836,-73.9673  40.6859,-73.9607

# %%
import sys
sys.path.append('C:\\Python27\\Lib\\site-packages')

# %%
from geopy.geocoders import Nominatim
import re
import time
import csv

# %%
geolocator = Nominatim()

# %%
def get_geocode(coord):
    time.sleep(0.5)
    addr = geolocator.reverse(coord, timeout=60).address
    if addr == None:
        zipcode = 'NaN'
        zone = 'NaN'
        county = 'NaN'
    else:
        strs = [x.strip() for x in addr.split(',')]
        num = str(re.findall(r"\D(\d{5})\D", addr))
        num = str(filter(str.isdigit, num))[:5]
        zipcode = num
        county = strs[-5]
        if strs[-6]=='Manhattan' or strs[-6]=='BK':
            zone = strs[-7]
        else:
            zone = strs[-6]
        #num = str(re.findall(r"\D(\d{5})\D", location.address))
        #num = str(filter(str.isdigit, num))
        #zipcode = num
    return zipcode+','+zone + ',' + county

# %%
def get_zipcode(zone):
    return zone.split(',')[0]
def get_neighborhood(zone):
    return zone.split(',')[1]
def get_county(zone):
    return zone.split(',')[2]

# %%
df.shape
# Out:
# (59904, 8)

# %%
L = len(df)
L
# Out:
# 59904

# %%
# since df is still too large to run, break it down to smaller pieces and then cat together to a large df

# %%
def add_fields(df):
    df['pickup_zone']=df['pickup_coord'].apply(get_geocode)
    df['pickup_zipcode'] = df['pickup_zone'].apply(get_zipcode)
    df['pickup_neighborhood'] = df['pickup_zone'].apply(get_neighborhood)
    df['pickup_county'] = df['pickup_zone'].apply(get_county)
    df['dropoff_zone']=df['dropoff_coord'].apply(get_geocode)
    df['dropoff_zipcode'] = df['dropoff_zone'].apply(get_zipcode)
    df['dropoff_neighborhood'] = df['dropoff_zone'].apply(get_neighborhood)
    df['dropoff_county'] = df['dropoff_zone'].apply(get_county)
    df.drop(['pickup_coord','dropoff_coord','pickup_zone','dropoff_zone'],axis=1,inplace=True)

# %%
test = df[:2].copy() #slice by copy, not by view, seeding with 1
test
# Out:
#            pickup_datetime  trip_time  trip_distance  passenger_count  hour  \
# 0  2015-04-12 00:40:18 UTC        160           0.29                1     0
# 1  2015-04-12 00:10:47 UTC        210           0.58                1     0
#
#    dayofweek      pickup_coord     dropoff_coord
# 0          1  40.6808,-73.9749  40.6846,-73.9777
# 1          1  40.6716,-73.9505   40.671,-73.9397

# %%
t0 = time.time()
add_fields(test)
t1 = time.time()-t0
t1
# Out:
# 4.670000076293945

# %%
test
# Out:
#            pickup_datetime  trip_time  trip_distance  passenger_count  hour  \
# 0  2015-04-12 00:40:18 UTC        160           0.29                1     0
# 1  2015-04-12 00:10:47 UTC        210           0.58                1     0
#
#    dayofweek pickup_zipcode pickup_neighborhood pickup_county dropoff_zipcode  \
# 0          1          11213         Fort Greene  Kings County           11217
# 1          1          11216       Crown Heights  Kings County           11213
#
#   dropoff_neighborhood dropoff_county
# 0          Fort Greene   Kings County
# 1      Eastern Parkway   Kings County

# %%
col = test.columns
col
# Out:
# Index([u'pickup_datetime', u'trip_time', u'trip_distance', u'passenger_count',
#        u'hour', u'dayofweek', u'pickup_zipcode', u'pickup_neighborhood',
#        u'pickup_county', u'dropoff_zipcode', u'dropoff_neighborhood',
#        u'dropoff_county'],
#       dtype='object')

# %%
# store all dataframe slice in dfs
def slice_dataframe(end,step,df):
    dfs=[]
    i = 0
    while i < end:
        if (i+step) > end:
                dfi = df[i:].copy()
        else:
            dfi = df[i:i+step].copy()
        dfs.append(dfi)
        i = i + step
    return dfs

# %%
dfs_all = slice_dataframe(L,10000,df)

# %%
len(dfs_all)
# Out:
# 6

# %%
i = 0 
result_df = pd.DataFrame(data=None, columns=col)
while i < L:
    add_fields(dfs_all[i])
    result_df = result_df.append(dfs_all[i],ignore_index = True)
    i = i + 1

# %% [markdown]
# # Data cleaning

# %%
result_df.dtypes
# Out:
# dayofweek               float64
# dropoff_county           object
# dropoff_neighborhood     object
# dropoff_zipcode         float64
# hour                    float64
# passenger_count         float64
# pickup_county            object
# pickup_datetime          object
# pickup_neighborhood      object
# pickup_zipcode          float64
# trip_distance           float64
# trip_time               float64
# dtype: object

# %%
# drop first column if 'Unnamed: 0',
# result_df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
# check NA zipcode
result_df['dropoff_zipcode'].isnull().sum()
# Out:
# 23

# %%
result_df['pickup_zipcode'].isnull().sum()
# Out:
# 13

# %%
# drop NA, keep index 
result_df.dropna(axis=0, how='any',inplace = True)
result_df.shape
# Out:
# (59868, 12)

# %%
# change float to int data type
result_df['dayofweek'] = result_df['dayofweek'].astype(int)
result_df['pickup_zipcode'] = result_df['pickup_zipcode'].astype(int)
result_df['dropoff_zipcode'] = result_df['dropoff_zipcode'].astype(int)
result_df['hour'] = result_df['hour'].astype(int)
result_df['passenger_count'] = result_df['passenger_count'].astype(int)
result_df.head()
# Out:
#    dayofweek dropoff_county dropoff_neighborhood  dropoff_zipcode  hour  \
# 0          1   Kings County          Fort Greene            11217     0
# 1          1   Kings County      Eastern Parkway            11213     0
# 2          1  Queens County          Kew Gardens            11415     0
# 3          1  Queens County      Jackson Heights            11370     0
# 4          1   Kings County   Bedford-Stuyvesant            11238     0
#
#    passenger_count  pickup_county          pickup_datetime  \
# 0                1   Kings County  2015-04-12 00:40:18 UTC
# 1                1   Kings County  2015-04-12 00:10:47 UTC
# 2                1  Queens County  2015-04-12 00:49:50 UTC
# 3                4  Queens County  2015-04-12 00:24:02 UTC
# 4                1   Kings County  2015-04-12 00:30:10 UTC
#
#   pickup_neighborhood  pickup_zipcode  trip_distance  trip_time
# 0         Fort Greene           11213           0.29      160.0
# 1       Crown Heights           11216           0.58      210.0
# 2              Queens           11415           0.90      249.0
# 3     Jackson Heights           11369           0.01       68.0
# 4    Prospect Heights           11238           0.57      248.0

# %%
result_df.tail()
# Out:
#        dayofweek dropoff_county dropoff_neighborhood  dropoff_zipcode  hour  \
# 59899          1   Kings County     Prospect Heights            11216    23
# 59900          1   Kings County         Williamsburg            11249    23
# 59901          1   Bronx County          High Bridge            10452    23
# 59902          1   Kings County            Flatlands            11210    23
# 59903          1  Queens County    Sunnyside Gardens            11101    23
#
#        passenger_count    pickup_county          pickup_datetime  \
# 59899                1     Kings County  2015-04-12 23:56:29 UTC
# 59900                1     Kings County  2015-04-12 23:17:13 UTC
# 59901                1  New York County  2015-04-12 23:59:20 UTC
# 59902                1     Kings County  2015-04-12 23:50:52 UTC
# 59903                5    Queens County  2015-04-12 23:05:18 UTC
#
#       pickup_neighborhood  pickup_zipcode  trip_distance  trip_time
# 59899        Williamsburg           11211           9.17     2494.0
# 59900         Boerum Hill           11201           2.81      523.0
# 59901    Hamilton Heights           10026           3.37      764.0
# 59902         Fort Greene           11217           5.47     1209.0
# 59903     Jackson Heights           11377           5.09     2014.0

# %%
# change weekday to Monday = 1
result_df['dayofweek']=result_df['dayofweek']-1
result_df['dayofweek']= np.where(result_df['dayofweek']== 0,7,result_df['dayofweek'])

# %%
result_df
# Out:
#        dayofweek   dropoff_county  \
# 0              7     Kings County
# 1              7     Kings County
# 2              7    Queens County
# 3              7    Queens County
# 4              7     Kings County
# 5              7    Queens County
# 6              7  New York County
# 7              7    Queens County
# 8              7     Kings County
# 9              7  New York County
# 10             7    Queens County
# 11             7     Kings County
# 12             7     Bronx County
# 13             7    Queens County
# 14             7  New York County
# 15             7    Queens County
# 16             7    Queens County
# 17             7     Kings County
# 18             7    Queens County
# 19             7    Queens County
# 20             7     Kings County
# 21             7    Queens County
# 22             7    Queens County
# 23             7     Kings County
# 24             7     Kings County
# 25             7  New York County
# 26             7    Queens County
# 27             7    Queens County
# 28             7    Queens County
# 29             7     Kings County
# ...          ...              ...
# 59874          7     Kings County
# 59875          7    Queens County
# 59876          7    Queens County
# 59877          7     Kings County
# 59878          7    Queens County
# 59879          7    Queens County
# 59880          7    Queens County
# 59881          7    Queens County
# 59882          7    Queens County
# 59883          7    Queens County
# 59884          7     Kings County
# 59885          7     Kings County
# 59886          7    Queens County
# 59887          7     Kings County
# 59888          7     Bronx County
# 59889          7    Queens County
# 59890          7    Queens County
# 59891          7     Kings County
# 59892          7     Kings County
# 59893          7     Kings County
# 59894          7  New York County
# 59895          7    Queens County
# 59896          7     Kings County
# 59897          7    Queens County
# 59898          7  New York County
# 59899          7     Kings County
# 59900          7     Kings County
# 59901          7     Bronx County
# 59902          7     Kings County
# 59903          7    Queens County
#
#                                  dropoff_neighborhood  dropoff_zipcode  hour  \
# 0                                         Fort Greene            11217     0
# 1                                     Eastern Parkway            11213     0
# 2                                         Kew Gardens            11415     0
# 3                                     Jackson Heights            11370     0
# 4                                  Bedford-Stuyvesant            11238     0
# 5                                     Jackson Heights            11368     0
# 6                                     Upper West Side            10025     0
# 7                                           Ridgewood            11385     0
# 8                                       Crown Heights            11238     0
# 9                                    Hamilton Heights            10031     0
# 10                                  Sunnyside Gardens            11103     0
# 11                                         Ocean Hill            11213     0
# 12                                         Mott Haven            10451     0
# 13                                          Sunnyside            11101     0
# 14                                             Harlem            10030     0
# 15                                        North Beach            11369     0
# 16                                           Woodside            11377     0
# 17                                         Greenpoint            11222     0
# 18                                    Jackson Heights            11373     0
# 19                                  Sunnyside Gardens            11103     0
# 20                                    Windsor Terrace            11218     0
# 21                                    Jackson Heights            11372     0
# 22                                             Corona            11368     0
# 23                                           Bushwick            11237     0
# 24                                       Williamsburg            11211     0
# 25                                        East Harlem            10029     0
# 26                                          Sunnyside            11101     0
# 27                                             Corona            11373     0
# 28                                             Queens            11435     0
# 29                                         Park Slope            11215     0
# ...                                               ...              ...   ...
# 59874                                   Crown Heights            11225    23
# 59875                                 Jackson Heights            11370    23
# 59876                                          Corona            11373    23
# 59877                                    Williamsburg            11249    23
# 59878                                          Queens            11367    23
# 59879                                          Corona            11368    23
# 59880                                     Morris Park            11420    23
# 59881                                             LIC            11101    23
# 59882                               Sunnyside Gardens            11106    23
# 59883                                          Corona            11368    23
# 59884                                     Fort Greene            11205    23
# 59885                                    Williamsburg            11211    23
# 59886                                        Steinway            11105    23
# 59887                                    Williamsburg            11211    23
# 59888                                           Bronx            10459    23
# 59889                                        Steinway            11105    23
# 59890                                        Steinway            11105    23
# 59891                                      Ocean Hill            11212    23
# 59892                                      Greenpoint            11222    23
# 59890          High Bridge           10451           5.93      955.0
# 59891          Cobble Hill           11217           4.85     1155.0
# 59892         Williamsburg           11211           2.40      579.0
# 59893           Park Slope           11217           4.00     1220.0
# 59894                  LIC           11101           3.54      511.0
# 59895              Jamaica           11435           3.55      590.0
# 59896         Williamsburg           11211           2.59      617.0
# 59897            Sunnyside           11101           2.92      998.0
# 59898         Williamsburg           11211           5.70     1125.0
# 59899         Williamsburg           11211           9.17     2494.0
# 59900          Boerum Hill           11201           2.81      523.0
# 59901     Hamilton Heights           10026           3.37      764.0
# 59902          Fort Greene           11217           5.47     1209.0
# 59903      Jackson Heights           11377           5.09     2014.0
#
# [59868 rows x 12 columns]

# %%
# clean zipcode to only include new york da zip code data
nyc_zipcode_df = pd.read_csv('zip_to_zcta10_nyc.csv')
nyc_zipcode = nyc_zipcode_df['ZIP'].values.tolist() #convert to list
nyc_zipcode
# Out:
# [10001L,
#  10002L,
#  10003L,
#  10004L,
#  10005L,
#  10006L,
#  10007L,
#  10008L,
#  10009L,
#  10010L,
#  10011L,
#  10012L,
#  10013L,
#  10014L,
#  10016L,
#  10017L,
#  10018L,
#  10019L,
#  10020L,
#  10021L,
#  10022L,
#  10023L,
#  10024L,
#  10025L,
#  10026L,
#  10027L,
#  10028L,
#  10029L,
#  10030L,
#  10031L,
#  10032L,
#  10033L,
#  10034L,
#  10035L,
#  10036L,
#  10037L,
#  10038L,
#  10039L,
#  10040L,
#  10041L,
#  10043L,
#  10044L,
#  10045L,
#  10055L,
#  10060L,
#  10065L,
#  10069L,
#  10075L,
#  10080L,
#  10081L,
#  10087L,
#  10090L,
#  10095L,
#  10101L,
#  10102L,
#  10103L,
#  10104L,
#  10105L,
#  10106L,
#  10107L,
#  10108L,
#  10109L,
#  10110L,
#  10111L,
#  10112L,
#  10113L,
#  10114L,
#  10115L,
#  10116L,
#  10117L,
#  10118L,
#  10119L,
#  10120L,
#  10121L,
#  10122L,
#  10123L,
#  10124L,
#  10125L,
#  10126L,
#  10128L,
#  10129L,
#  10130L,
#  10131L,
#  10132L,
#  10133L,
#  10138L,
#  10150L,
#  10151L,
#  10152L,
#  10153L,
#  10154L,
#  10155L,
#  10156L,
#  10157L,
#  10158L,
#  10159L,
#  10160L,
#  10161L,
#  10162L,
#  10163L,
#  10164L,
#  10165L,
#  10166L,
#  10167L,
#  10168L,
#  10169L,
#  10170L,
#  10171L,
#  10172L,
#  10173L,
#  10174L,
#  10175L,
#  10176L,
#  10177L,
#  10178L,
#  10179L,
#  10185L,
#  10199L,
#  10203L,
#  10211L,
#  10212L,
#  10213L,
#  10242L,
#  10249L,
#  10256L,
#  10257L,
#  10258L,
#  10259L,
#  10260L,
#  10261L,
#  10265L,
#  10268L,
#  10269L,
#  10270L,
#  10271L,
#  10272L,
#  10273L,
#  10274L,
#  10275L,
#  10276L,
#  10277L,
#  10278L,
#  10279L,
#  10280L,
#  10281L,
#  10282L,
#  10285L,
#  10286L,
#  10292L,
#  10301L,
#  10302L,
#  10303L,
#  10304L,
#  10305L,
#  10306L,
#  10307L,
#  10308L,
#  10309L,
#  10310L,
#  10311L,
#  10312L,
#  10313L,
#  10314L,
#  10451L,
#  10452L,
#  10453L,
#  10454L,
#  10455L,
#  10456L,
#  10457L,
#  10458L,
#  10459L,
#  10460L,
#  10461L,
#  10462L,
#  10463L,
#  10464L,
#  10465L,
#  10466L,
#  10467L,
#  10468L,
#  10469L,
#  10470L,
#  10471L,
#  10472L,
#  10473L,
#  10474L,
#  10475L,
#  10499L,
#  11004L,
#  11005L,
#  11101L,
#  11102L,
#  11103L,
#  11104L,
#  11105L,
#  11106L,
#  11109L,
#  11120L,
#  11201L,
#  11202L,
#  11203L,
#  11204L,
#  11205L,
#  11206L,
#  11207L,
#  11208L,
#  11209L,
#  11210L,
#  11211L,
#  11212L,
#  11213L,
#  11214L,
#  11215L,
#  11216L,
#  11217L,
#  11218L,
#  11219L,
#  11220L,
#  11221L,
#  11222L,
#  11223L,
#  11224L,
#  11225L,
#  11226L,
#  11228L,
#  11229L,
#  11230L,
#  11231L,
#  11232L,
#  11233L,
#  11234L,
#  11235L,
#  11236L,
#  11237L,
#  11238L,
#  11239L,
#  11241L,
#  11242L,
#  11243L,
#  11245L,
#  11247L,
#  11249L,
#  11251L,
#  11252L,
#  11256L,
#  11351L,
#  11352L,
#  11354L,
#  11355L,
#  11356L,
#  11357L,
#  11358L,
#  11359L,
#  11360L,
#  11361L,
#  11362L,
#  11363L,
#  11364L,
#  11365L,
#  11366L,
#  11367L,
#  11368L,
#  11369L,
#  11370L,
#  11371L,
#  11372L,
#  11373L,
#  11374L,
#  11375L,
#  11377L,
#  11378L,
#  11379L,
#  11380L,
#  11381L,
#  11385L,
#  11386L,
#  11390L,
#  11405L,
#  11411L,
#  11412L,
#  11413L,
#  11414L,
#  11415L,
#  11416L,
#  11417L,
#  11418L,
#  11419L,
#  11420L,
#  11421L,
#  11422L,
#  11423L,
#  11424L,
#  11425L,
#  11426L,
#  11427L,
#  11428L,
#  11429L,
#  11430L,
#  11431L,
#  11432L,
#  11433L,
#  11434L,
#  11435L,
#  11436L,
#  11439L,
#  11451L,
#  11499L,
#  11690L,
#  11691L,
#  11692L,
#  11693L,
#  11694L,
#  11695L,
#  11697L]

# %%
result_df  = result_df[result_df['pickup_zipcode'].isin(nyc_zipcode)]
result_df  = result_df[result_df['dropoff_zipcode'].isin(nyc_zipcode)]

# %%
# make county consistant
result_df['pickup_county'] = np.where(result_df['pickup_county'] == 'Kings','Kings County',result_df['pickup_county'])
result_df['dropoff_county'] = np.where(result_df['dropoff_county'] == 'Kings','Kings County',result_df['dropoff_county'])

# %%
result_df.shape
# Out:
# (59276, 12)

# %%
result_df.to_csv('green_wk15_sun_zone.csv')

# %% [markdown]
# ## Geocoder Test Case

# %%
c0 = df['dropoff_coord'].iloc[702]
c0
# Out:
# '40.6528,-74.0061'

# %%
# check the weird output 
geolocator.reverse(c0).address
# Out:
# u'998, 4th Avenue, Sunset Park, Kings County, NYC, New York, 11232, United States of America'

# %%
get_geocode(c0)
# Out:
# u'11232,Sunset Park,Kings County'
